# %%
import sys
import os
from pathlib import Path

print("Python executable:")
print(sys.executable)

print("\nPython version:")
print(sys.version)

print("\nCurrent working directory:")
print(Path.cwd())
# Out:
# Python executable:
# c:\Users\divya\OneDrive\Desktop\Programming\dev\Leh-NVDI-Analysis\venv\Scripts\python.exe
#
# Python version:
# 3.13.15 (tags/v3.13.15:4061bc4, Aug  5 2026, 13:05:39) [MSC v.1944 64 bit (AMD64)]
#
# Current working directory:
# c:\Users\divya\OneDrive\Desktop\Programming\dev\Leh-NVDI-Analysis\notebooks

# %%
import ee
import geemap

print("Earth Engine API imported successfully.")
print("geemap imported successfully.")

print("Earth Engine version:", ee.__version__)
# Out:
# Earth Engine API imported successfully.
# geemap imported successfully.
# Earth Engine version: 1.7.43

# %%
import ee

ee.Authenticate()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# <p>To authorize access needed by Earth Engine, open the following
#         URL in a web browser and follow the instructions:</p>
#         <p><a href=https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=nCuRG6twUC9qY0dyI6bPZubA8ehtOPq45PHwzB55fbg&tc=Nx0M1D9Q4PX7SMcj2Bu3cedIY3hvqQis4C6lYHUkihE&cc=GTmL3kdXf4R9BVot3R9k6BoT0O1m5zS3Uu1FcaWGyxc>https://code.earthengine.google.com/client-auth?scopes=https%3A//www.googleapis.com/auth/earthengine%20https%3A//www.googleapis.com/auth/cloud-platform%20https%3A//www.googleapis.com/auth/drive%20https%3A//www.googleapis.com/auth/devstorage.full_control&request_id=nCuRG6twUC9qY0dyI6bPZubA8ehtOPq45PHwzB55fbg&tc=Nx0M1D9Q4PX7SMcj2Bu3cedIY3hvqQis4C6lYHUkihE&cc=GTmL3kdXf4R9BVot3R9k6BoT0O1m5zS3Uu1FcaWGyxc</a></p>
#         <p>The authorization workflow will generate a code, which you should paste in the box below.</p>
# Successfully saved authorization token.

# %%
ee.Initialize()

print("Earth Engine initialized successfully.")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Earth Engine initialized successfully.

# %%
image_collection = ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")

image_count = image_collection.size().getInfo()

print("Landsat image count:", image_count)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Landsat image count: 2065571

# %%
image = image_collection.first()

print("First image:")
print(image.getInfo()["id"])
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# First image:
# LANDSAT/LC08/C02/T1_L2/LC08_001004_20140609
